# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd #to clean

# %%
# Load the Excel file
excel_file = pd.ExcelFile('datos_actividad2.xlsx')

# Parse each sheet into a DataFrame
df = excel_file.parse('Hoja2')
df2 = excel_file.parse('Hoja3')

# %%
#See second sheet
print(list(df2))
# Out:
# ['CustomerID', 'BikeBuyer', 'AvgMonthSpend', 'CustomerID.1']

# %%
#see the first sheet
df.head(2)
# Out:
#    CustomerID Title FirstName MiddleName LastName Suffix         AddressLine1  \
# 0       21173   NaN      Chad          C     Yuan    NaN   7090 C. Mount Hood
# 1       13249   NaN      Ryan        NaN    Perry    NaN  3651 Willow Lake Rd
#
#   AddressLine2        City StateProvinceName  ... MaritalStatus HomeOwnerFlag  \
# 0          NaN  Wollongong   New South Wales  ...             M             1
# 1          NaN     Shawnee  British Columbia  ...             M             1
#
#   NumberCarsOwned NumberChildrenAtHome TotalChildren YearlyIncome LastUpdated  \
# 0               3                    0             1        81916  2017-03-06
# 1               2                    1             2        81076  2017-03-06
#
#   BikeBuyer  AvgMonthSpend  BikeBuyerText
# 0         1          50.97            YES
# 1         1          53.11            YES
#
# [2 rows x 27 columns]

# %%
#See the variables of the first sheet
print(list(df))
# Out:
# ['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName', 'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate', 'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome', 'LastUpdated', 'BikeBuyer', 'AvgMonthSpend', 'BikeBuyerText']

# %%
# Columns to drop by index
columns_to_drop = list(range(13)) + [14, 15, 26]

# %%
drop_df=df.drop(df.columns[columns_to_drop], axis=1)

# %%
drop_df.head(2)
# Out:
#    BirthDate Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0 1987-11-13      M             M              1                3
# 1 1972-07-21      M             M              1                2
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome LastUpdated  BikeBuyer  \
# 0                     0              1         81916  2017-03-06          1
# 1                     1              2         81076  2017-03-06          1
#
#    AvgMonthSpend
# 0          50.97
# 1          53.11

# %%
#Calculate age based on 'LastUpdated' and 'BirthDate'

# Convert 'BirthDate' and 'LastUpdated' columns to datetime
drop_df['BirthDate'] = pd.to_datetime(drop_df['BirthDate'])
drop_df['LastUpdated'] = pd.to_datetime(drop_df['LastUpdated'])

# %%
# Calculate age by subtracting the year of 'BirthDate' from 'LastUpdated'
drop_df['Age'] = drop_df['LastUpdated'].dt.year - drop_df['BirthDate'].dt.year
drop_df.head(2)
# Out:
#    BirthDate Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0 1987-11-13      M             M              1                3
# 1 1972-07-21      M             M              1                2
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome LastUpdated  BikeBuyer  \
# 0                     0              1         81916  2017-03-06          1
# 1                     1              2         81076  2017-03-06          1
#
#    AvgMonthSpend  Age
# 0          50.97   30
# 1          53.11   45

# %%
# List of column indices to drop
columns_to_drop = [0, 8]

# %%
# Drop the specified columns
drop_df = drop_df.drop(drop_df.columns[columns_to_drop], axis=1)
drop_df.head(2)
# Out:
#   Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  NumberChildrenAtHome  \
# 0      M             M              1                3                     0
# 1      M             M              1                2                     1
#
#    TotalChildren  YearlyIncome  BikeBuyer  AvgMonthSpend  Age
# 0              1         81916          1          50.97   30
# 1              2         81076          1          53.11   45

# %%
#we are going to encode the 'Gender' and 'MaritalStatus'
encoded_df = pd.DataFrame(drop_df)

# Defining mapping dictionary for 'Gender' and 'MaritalStatus'
gender_mapping = {'M': 0, 'F': 1}
marital_mapping = {'S': 0, 'M': 1}

# %%
#replace to map the values
encoded_df['Gender'] = encoded_df['Gender'].replace(gender_mapping)
encoded_df['MaritalStatus'] = encoded_df['MaritalStatus'].replace(marital_mapping)

# %%
encoded_df.head(2)
# Out:
#    Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0       0              1              1                3
# 1       0              1              1                2
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  BikeBuyer  \
# 0                     0              1         81916          1
# 1                     1              2         81076          1
#
#    AvgMonthSpend  Age
# 0          50.97   30
# 1          53.11   45

# %%
list(encoded_df)
# Out:
# ['Gender',
#  'MaritalStatus',
#  'HomeOwnerFlag',
#  'NumberCarsOwned',
#  'NumberChildrenAtHome',
#  'TotalChildren',
#  'YearlyIncome',
#  'BikeBuyer',
#  'AvgMonthSpend',
#  'Age']

# %%
# Move 'BikeBuyer' column to the last position

cols = list(encoded_df.columns)
if 'BikeBuyer' in cols:
    cols.remove('BikeBuyer')
cols = cols + ['BikeBuyer']  # Move 'BikeBuyer' to last position
encoded_df = encoded_df[cols]

# %%
encoded_df.head(2)
# Out:
#    Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0       0              1              1                3
# 1       0              1              1                2
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  AvgMonthSpend  Age  \
# 0                     0              1         81916          50.97   30
# 1                     1              2         81076          53.11   45
#
#    BikeBuyer
# 0          1
# 1          1

# %%
print(list(encoded_df))
# Out:
# ['Gender', 'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome', 'AvgMonthSpend', 'Age', 'BikeBuyer']

# %%
dataset = encoded_df

# %%
dataset.head(2)
# Out:
#    Gender  MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 0       0              1              1                3
# 1       0              1              1                2
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome  AvgMonthSpend  Age  \
# 0                     0              1         81916          50.97   30
# 1                     1              2         81076          53.11   45
#
#    BikeBuyer
# 0          1
# 1          1

# %%
# Export to Excel file (download it in the file directory of colab )
dataset.to_excel('AW-Bikes_cleaned_dataset.xlsx', index=False)
